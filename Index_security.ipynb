# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Caricare il dataset scaricato al link https://www.kaggle.com/datasets/katerynameleshenko/cyber-security-indexes
df=pd.read_csv('Cyber_security.csv') #dati relativi a NCSI aggiornati a gennaio 2023

# %%
df.head()
# Out:
#        Country        Region    CEI    GCI   NCSI    DDL
# 0  Afghanistan  Asia-Pasific  1.000   5.20  11.69  19.50
# 1      Albania        Europe  0.566  64.32  62.34  48.74
# 2      Algeria        Africa  0.721  33.95  33.77  42.81
# 3      Andorra        Europe    NaN  26.38    NaN    NaN
# 4       Angola        Africa    NaN  12.99   9.09  22.69

# %%
df_Europe = df[df['Region']=='Europe'].reset_index().drop(columns=['index'])

# %%
df_Europe
# Out:
#                    Country  Region    CEI    GCI   NCSI    DDL
# 0                  Albania  Europe  0.566  64.32  62.34  48.74
# 1                  Andorra  Europe    NaN  26.38    NaN    NaN
# 2                  Armenia  Europe  0.655  50.47  35.06  55.06
# 3                  Austria  Europe  0.162  93.89  68.83  75.76
# 4               Azerbaijan  Europe  0.531  89.31  59.74  54.78
# 5                  Belarus  Europe  0.614  50.57  53.25  62.33
# 6                  Belgium  Europe  0.190  96.25  94.81  74.07
# 7   Bosnia and Herzegovina  Europe  0.583  29.44  28.57  49.31
# 8                 Bulgaria  Europe  0.483  67.38  74.03  62.06
# 9                  Croatia  Europe  0.255  92.53  83.12  81.51
# 10                  Cyprus  Europe  0.334  88.82  66.23  68.83
# 11          Czech Republic  Europe  0.334  74.37  92.21  69.21
# 12                 Denmark  Europe  0.117  92.60  84.42  82.68
# 13                 Estonia  Europe  0.134  99.48  93.51  75.59
# ...

# %%
df_Europe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  48 non-null     object
#  1   Region   48 non-null     object
#  2   CEI      41 non-null     float64
#  3   GCI      47 non-null     float64
#  4   NCSI     47 non-null     float64
#  5   DDL      43 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 2.4+ KB

# %%
print(df_Europe.loc[df_Europe['NCSI'].isna()].index)
# Out:
# Index([1], dtype='int64')

# %%
df_Europe.loc[1] #Unico valore nullo di NCSI è per Andorra
# Out:
# Country    Andorra
# Region      Europe
# CEI            NaN
# GCI          26.38
# NCSI           NaN
# DDL            NaN
# Name: 1, dtype: object

# %%
df_Europe[df_Europe['Country'] == 'Italy']
# Out:
#    Country  Region    CEI    GCI   NCSI    DDL
# 22   Italy  Europe  0.269  96.13  79.22  67.26

# %%
#L'italia nel 2023 ha un punteggio di NCSI index del 79,22. Ciò significa che risponde bene alle minacce cyber però con dei margini di miglioramento

# %%
df_Europe[['Country', 'NCSI']].sort_values('NCSI', ascending=False).reset_index().drop(columns=['index'])
# Out:
#                    Country   NCSI
# 0                   Greece  96.10
# 1                  Belgium  94.81
# 2                Lithuania  93.51
# 3                  Estonia  93.51
# 4           Czech Republic  92.21
# 5                  Germany  90.91
# 6                 Portugal  89.61
# 7           United Kingdom  89.61
# 8                  Romania  89.61
# 9                    Spain  88.31
# 10                  Poland  87.01
# 11                 Finland  85.71
# 12                  France  84.42
# 13                  Sweden  84.42
# 14                 Denmark  84.42
# 15                 Croatia  83.12
# 16                Slovakia  83.12
# 17             Netherlands  83.12
# 18                  Serbia  80.52
# 19                   Italy  79.22
# 20             Switzerland  76.62
# 21                 Ireland  75.32
# 22                  Latvia  75.32
# 23                 Ukraine  75.32
# 24                Bulgaria  74.03
# 25                  Russia  71.43
# ...

# %%
df_Europe['NCSI'].mean()
# Out:
# 69.07340425531915

# %%
#primo posto: Grecia
#secondo posto:belgio
#terzo posto: lituania

#l'italia si colloca al ventesimo posto in Europa, più o meno a metà (dati aggiornati a gennaio 2023)

# %%
#Mentre ad ottobre 2024 il valore dell'italia è arrivato al 88 collocandosi al quarto posto

# %%
import requests
from bs4 import BeautifulSoup

# %%
url ='https://ncsi.ega.ee/ncsi-index/'
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
lista=['al', 'ad', 'am', 'at', 'az', 'by', 'be', 'ba', 'bg', 'hr', 'cy', 'cz', 'dk', 'ee', 'fi', 'fr', 'ge', 'de', 'gr', 'hu', 'is', 'ie', 'it','lv',
       'li', 'lt', 'lu', 'mk', 'mt', 'md', 'mc', 'me', 'nl', 'no', 'pl', 'pt', 'ro', 'ru', 'sm', 'rs', 'sk', 'si', 'es', 'se', 'ch', 'ua', 'gb', 'va']

# %%
lista_1=['al','at','az','be','ba','cy','cz','ee','ge','ie', 'it', 'lv','lt','me', 'md','nl', 'mk','pl','pt','rs','sk','ua','gb']

# %%
len(lista)
# Out:
# 48

# %%
countries=[]
for i in lista_1:
 country=soup.find_all('a', href='/country/'+i+'/')[1].text
 countries.append(country)

# %%
countries
# Out:
# ['Albania',
#  'Austria',
#  'Azerbaijan',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Cyprus',
#  'Czech Republic',
#  'Estonia',
#  'Georgia',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Montenegro',
#  'Moldova (Republic of)',
#  'Netherlands',
#  'North Macedonia',
#  'Poland',
#  'Portugal',
#  'Serbia',
#  'Slovakia',
#  'Ukraine',
#  'United Kingdom']

# %%
len(countries)
# Out:
# 23

# %%
df_NCSI_2023=pd.DataFrame({'Country': ['Belgio', 'Lituania', 'Estonia', 'Repubblica Ceca', 'Germania', 'Italia', 'UE'], 
                           'NCSI': [98.81, 93.51, 93.51, 90.91, 90.91, 79.22, 81.6]
    
}
)

# %%
df_NCSI_2023   #italia: posto 23
# Out:
#            Country   NCSI
# 0           Belgio  98.81
# 1         Lituania  93.51
# 2          Estonia  93.51
# 3  Repubblica Ceca  90.91
# 4         Germania  90.91
# 5           Italia  79.22
# 6               UE  81.60

# %%
df_NCSI_2024=pd.DataFrame({'Country': ['Repubblica Ceca', 'Polonia', 'Belgio', 'Italia', 'Estonia', 'UE'], 
                           'NCSI': [98.33, 92.50, 92.50, 88.33, 88.33, 85.37] 
    
}
    
)
#ci sono 13 paesi

# %%
df_NCSI_2024
# Out:
#            Country   NCSI
# 0  Repubblica Ceca  98.33
# 1          Polonia  92.50
# 2           Belgio  92.50
# 3           Italia  88.33
# 4          Estonia  88.33
# 5               UE  85.37

# %%
#Abbiamo provato a utilizzare la tecnica del web scraping per estrarre dati dalla pagina https://ncsi.ega.ee/ncsi-index/?order=-isd ma per la realizzazione della presentazione in Tableau li abbiamo estrapolati "a mano"
